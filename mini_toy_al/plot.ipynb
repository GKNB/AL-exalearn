y41 = [0.0001843994118904418, 0.000140458339364572, 0.00018331123883348312, 9.050157696249321e-05, 0.00010419244845061937, 0.00016407958283556675, 0.0002280552344549508, 0.0002792043562325209, 8.86037769908846e-05, 0.00019691054705556652, 0.0002493472204808926, 0.00018443140266941572, 0.00044009315512983055, 9.247560630576441e-05, 7.516297060815092e-05, 0.00023501752435911628, 0.00010828435921555394, 0.00021625843862991802, 0.0010034739279394782, 0.00010649518814399633]
y42 = [7.4248296072078e-05, 5.339027164615331e-05, 0.00014726370494059962, 6.954998134473207e-05, 6.492988151409474e-05, 9.83253238243712e-05, 0.00020221264748460535, 0.00011047229336960771, 4.2537448852794535e-05, 7.545015864303326e-05, 0.00016871610947589638, 6.866364351727426e-05, 0.00042584823107891956, 0.00010506843129702138, 3.1819773364041394e-05, 0.0001301218380072897, 6.129527533389174e-05, 0.00034264974560794365, 0.001267019696631207, 2.2856579090576858e-05]

y51 = [9.02670263093271e-05, 5.5010423303188614e-05, 0.0001624393785016679, 9.143436962650474e-05, 0.00024397209652918426, 0.00010891986862175248, 0.0002525390613661608, 0.0002326618576410996, 7.217395814373806e-05, 0.0001551015928568084, 0.00030466835706806247, 0.00017229983889778904, 0.0023069476985882447, 9.11318958189079e-05, 6.758135622609902e-05, 0.00025248165799039496, 8.727168496269771e-05, 0.0002712952309211347, 0.0011703754193346174, 9.060231588204366e-05]

# %%
plt.figure(figsize=(8, 6))

x = np.arange(20)
# Plot y1 and y2 against x
plt.plot(x, y11, label='small data', marker='o')
plt.plot(x, y12, label='large data with al', marker='s')
plt.plot(x, y21, label='large data no al', marker='p')

# Set labels and title
plt.xlabel('x')
plt.ylabel('Values')
plt.title('Plotting PyTorch Tensors')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
plt.figure(figsize=(8, 6))

x = np.arange(20)
# Plot y1 and y2 against x
plt.plot(x, y21, label='small data', marker='o')
plt.plot(x, y22, label='large data with al', marker='s')
plt.plot(x, y31, label='large data no al', marker='p')

# Set labels and title
plt.xlabel('x')
plt.ylabel('Values')
plt.title('Plotting PyTorch Tensors')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
plt.figure(figsize=(8, 6))

x = np.arange(20)
# Plot y1 and y2 against x
plt.plot(x, y31, label='small data', marker='o')
plt.plot(x, y32, label='large data with al', marker='s')
plt.plot(x, y41, label='large data no al', marker='p')

# Set labels and title
plt.xlabel('x')
plt.ylabel('Values')
plt.title('Plotting PyTorch Tensors')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
plt.figure(figsize=(8, 6))

x = np.arange(20)
# Plot y1 and y2 against x
plt.plot(x, y41, label='small data', marker='o')
plt.plot(x, y42, label='large data with al', marker='s')
plt.plot(x, y51, label='large data no al', marker='p')

# Set labels and title
plt.xlabel('x')
plt.ylabel('Values')
plt.title('Plotting PyTorch Tensors')

# Add a legend
plt.legend()

# Show the plot
plt.show()
