# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(8, 6))

x = np.arange(20)
y1 = [0.055441357, 0.047553573, 0.073349155, 0.054439105, 0.06859983, 0.018102854, 0.05349456, 0.07529423, 0.05211323, 0.040444627, 0.042471625, 0.02982639, 0.07524431, 0.044785187, 0.010779799, 0.10155229, 0.015095523, 0.028692393, 0.024614556, 0.03550931]
y2 = [0.039206542, 0.02144092, 0.042788986, 0.028594771, 0.056048647, 0.031204687, 0.045385942, 0.033911552, 0.03588407, 0.03247023, 0.038099337, 0.01832893, 0.06627522, 0.014717007, 0.0045402814, 0.030764027, 0.010244569, 0.014682395, 0.019891525, 0.014844185]
y3 = [0.04224294, 0.034149766, 0.05739125, 0.042608954, 0.047970384, 0.011611519, 0.042905338, 0.05303779, 0.041580074, 0.0326641, 0.03562721, 0.020709153, 0.064378805, 0.026964363, 0.008104453, 0.07728837, 0.01181929, 0.01956319, 0.01653277, 0.027476067]
# Plot y1 and y2 against x
plt.plot(x, y1, label='small data', marker='o')
plt.plot(x, y2, label='large data with al', marker='s')
plt.plot(x, y3, label='large data no al', marker='p')

# Set labels and title
plt.xlabel('x')
plt.ylabel('Values')
plt.title('Plotting PyTorch Tensors')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
plt.figure(figsize=(8, 6))

x = np.arange(20)
y1 = [0.04224294, 0.034149766, 0.05739125, 0.042608954, 0.047970384, 0.011611519, 0.042905338, 0.05303779, 0.041580074, 0.0326641, 0.03562721, 0.020709153, 0.064378805, 0.026964363, 0.008104453, 0.07728837, 0.01181929, 0.01956319, 0.01653277, 0.027476067]
y2 = [0.02083096, 0.00849279, 0.008630225, 0.010842157, 0.023379467, 0.0033268814, 0.023310998, 0.01410466, 0.010703694, 0.018397301, 0.02031455, 0.0052985926, 0.04768797, 0.0053863027, 0.0022457992, 0.009436008, 0.0037400753, 0.0051575396, 0.005337798, 0.006844681]
y3 = [0.029437184, 0.022497656, 0.032173757, 0.028644485, 0.02895238, 0.00722254, 0.033426538, 0.037551835, 0.02385736, 0.026670162, 0.029911553, 0.014646108, 0.0570154, 0.015286224, 0.0071633765, 0.043569785, 0.009621538, 0.01306405, 0.010971301, 0.01723904]
# Plot y1 and y2 against x
plt.plot(x, y1, label='small data', marker='o')
plt.plot(x, y2, label='large data with al', marker='s')
plt.plot(x, y3, label='large data no al', marker='p')

# Set labels and title
plt.xlabel('x')
plt.ylabel('Values')
plt.title('Plotting PyTorch Tensors')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
plt.figure(figsize=(8, 6))

x = np.arange(20)
y1 = [0.029437184, 0.022497656, 0.032173757, 0.028644485, 0.02895238, 0.00722254, 0.033426538, 0.037551835, 0.02385736, 0.026670162, 0.029911553, 0.014646108, 0.0570154, 0.015286224, 0.0071633765, 0.043569785, 0.009621538, 0.01306405, 0.010971301, 0.01723904]
y2 = [0.003973848, 0.0031851232, 0.0025785523, 0.002349757, 0.004167422, 0.0024523225, 0.0072481153, 0.0022253839, 0.0023323263, 0.0027055172, 0.0027569092, 0.0031774873, 0.039037526, 0.0030279004, 0.0013902221, 0.003085115, 0.001962075, 0.0023218808, 0.0015826364, 0.001744762]
y3 = [0.016667973958483292, 0.012788086319150776, 0.014258608088119367, 0.017853177280074805, 0.01994109915485943, 0.0063699062012881, 0.021757396764904915, 0.03348564486780929, 0.013804212304761495, 0.01578091803603391, 0.017269762894411896, 0.010195281307745949, 0.04263667780627963, 0.008859950399989753, 0.00643093491971564, 0.01779780328672803, 0.007848463498285482, 0.0075397873165085, 0.007681530815691295, 0.011289814470988492]
# Plot y1 and y2 against x
plt.plot(x, y1, label='small data', marker='o')
plt.plot(x, y2, label='large data with al', marker='s')
plt.plot(x, y3, label='large data no al', marker='p')

# Set labels and title
plt.xlabel('x')
plt.ylabel('Values')
plt.title('Plotting PyTorch Tensors')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
plt.figure(figsize=(8, 6))

x = np.arange(20)
y1 = [0.016667973958483292, 0.012788086319150776, 0.014258608088119367, 0.017853177280074805, 0.01994109915485943, 0.0063699062012881, 0.021757396764904915, 0.03348564486780929, 0.013804212304761495, 0.01578091803603391, 0.017269762894411896, 0.010195281307745949, 0.04263667780627963, 0.008859950399989753, 0.00643093491971564, 0.01779780328672803, 0.007848463498285482, 0.0075397873165085, 0.007681530815691295, 0.011289814470988492]
y2 = [0.0011957705612759353, 0.0015501585704295814, 0.0019258351452706875, 0.0014071074234319832, 0.0012893635183113148, 0.0017606986972004933, 0.0022094289064506674, 0.0012414928768683226, 0.0017250439251175536, 0.0015031451325773569, 0.0017061627210596226, 0.0024107673046774697, 0.03181189495084362, 0.002198122370364655, 0.0010993549159954567, 0.0015119307167543621, 0.0011823229872916275, 0.0018334698606220499, 0.0010409738870690395, 0.0012858761632944798]
y3 = [0.010267214504447397, 0.00979083364814097, 0.0102654494963917, 0.012809408681857775, 0.011440646972238734, 0.0068328401941853715, 0.011032712094542055, 0.03380741927004161, 0.0076201131369597105, 0.007824633882841577, 0.008018819134884978, 0.008139263456043606, 0.0431196328282392, 0.006894188277239702, 0.006923615670232144, 0.010845286275756812, 0.007563342971260121, 0.007267734067431681, 0.00709130080357299, 0.007239951641682333]
# Plot y1 and y2 against x
plt.plot(x, y1, label='small data', marker='o')
plt.plot(x, y2, label='large data with al', marker='s')
plt.plot(x, y3, label='large data no al', marker='p')

# Set labels and title
plt.xlabel('x')
plt.ylabel('Values')
plt.title('Plotting PyTorch Tensors')

# Add a legend
plt.legend()

# Show the plot
plt.show()
